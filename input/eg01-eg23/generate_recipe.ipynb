# %%
# blanket and driver compositions
import numpy as np
with open('recipe_text', 'r') as f:
    lines = f.readlines()
    array = np.array(['isotope','driver_fresh', 'driver_used', 'blanket_fresh', 'blanket_used'])
    for line in lines[1:]:
        organized = ' '.join(line.split())
        organized = organized.split(' ')
        array = np.vstack((array, organized))
    isotope_array = array

# %%
string = """

<recipe> 
	<name>EG01_fresh_recipe</name>
	<basis>mass</basis>
	<nuclide>
		<id>U234</id>
		<comp>0.000337</comp>
	</nuclide>
	<nuclide>
		<id>U235</id>
		<comp>0.042079</comp>
	</nuclide>
	<nuclide>
		<id>U238</id>
		<comp>0.957584</comp>
	</nuclide>
</recipe>



<recipe> 
	<name>EG01_used_recipe</name>
	<basis>mass</basis>
	<nuclide>
		<id>Ag107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag108m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag109</id>
		<comp>0.000115</comp>
	</nuclide>
	<nuclide>
		<id>Ag109m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag110</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag110m</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Ag111</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Ag111m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag112</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag113m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag115</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag116</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag117</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Am240</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Am241</id>
		<comp>0.000064</comp>
	</nuclide>
	<nuclide>
		<id>Am242</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Am242m</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Am243</id>
		<comp>0.000197</comp>
	</nuclide>
	<nuclide>
		<id>Am244</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As75</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As76</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As77</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As78</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As79</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As80</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As81</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As82</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As82m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As83</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As84</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba134</id>
		<comp>0.000113</comp>
	</nuclide>
	<nuclide>
		<id>Ba135</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Ba135m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba136</id>
		<comp>0.000043</comp>
	</nuclide>
	<nuclide>
		<id>Ba137</id>
		<comp>0.000086</comp>
	</nuclide>
	<nuclide>
		<id>Ba137m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba138</id>
		<comp>0.001939</comp>
	</nuclide>
	<nuclide>
		<id>Ba139</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba140</id>
		<comp>0.000021</comp>
	</nuclide>
	<nuclide>
		<id>Ba141</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba143</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba144</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba145</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba147</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Be10</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Be9</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Bk249</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br79</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br81</id>
		<comp>0.000032</comp>
	</nuclide>
	<nuclide>
		<id>Br82</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br82m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br83</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br84</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br84m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br85</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br86</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br87</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br88</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br89</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br90</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>C14</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd108</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd109</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd110</id>
		<comp>0.000076</comp>
	</nuclide>
	<nuclide>
		<id>Cd111</id>
		<comp>0.000045</comp>
	</nuclide>
	<nuclide>
		<id>Cd111m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd112</id>
		<comp>0.000027</comp>
	</nuclide>
	<nuclide>
		<id>Cd113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd113m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd114</id>
		<comp>0.000035</comp>
	</nuclide>
	<nuclide>
		<id>Cd115</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd115m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd116</id>
		<comp>0.000013</comp>
	</nuclide>
	<nuclide>
		<id>Cd117</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd117m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd118</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd119</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd119m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd120</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd121</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd123</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd124</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce140</id>
		<comp>0.001869</comp>
	</nuclide>
	<nuclide>
		<id>Ce141</id>
		<comp>0.000052</comp>
	</nuclide>
	<nuclide>
		<id>Ce142</id>
		<comp>0.001709</comp>
	</nuclide>
	<nuclide>
		<id>Ce143</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Ce144</id>
		<comp>0.000383</comp>
	</nuclide>
	<nuclide>
		<id>Ce145</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce147</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce148</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce149</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce150</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cf249</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cf250</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cm241</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cm242</id>
		<comp>0.000026</comp>
	</nuclide>
	<nuclide>
		<id>Cm243</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Cm244</id>
		<comp>0.000084</comp>
	</nuclide>
	<nuclide>
		<id>Cm245</id>
		<comp>0.000006</comp>
	</nuclide>
	<nuclide>
		<id>Cm246</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Cm247</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cm248</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs133</id>
		<comp>0.001599</comp>
	</nuclide>
	<nuclide>
		<id>Cs134</id>
		<comp>0.000230</comp>
	</nuclide>
	<nuclide>
		<id>Cs134m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs135</id>
		<comp>0.000645</comp>
	</nuclide>
	<nuclide>
		<id>Cs135m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs136</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Cs137</id>
		<comp>0.001799</comp>
	</nuclide>
	<nuclide>
		<id>Cs138</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs138m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs139</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs140</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs141</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs143</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cs144</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Dy160</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Dy161</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy162</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy163</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy164</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Dy165</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Dy166</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er166</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er167</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er168</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er169</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu152m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu153</id>
		<comp>0.000194</comp>
	</nuclide>
	<nuclide>
		<id>Eu154</id>
		<comp>0.000066</comp>
	</nuclide>
	<nuclide>
		<id>Eu155</id>
		<comp>0.000026</comp>
	</nuclide>
	<nuclide>
		<id>Eu156</id>
		<comp>0.000005</comp>
	</nuclide>
	<nuclide>
		<id>Eu157</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu158</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu159</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu160</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu162</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga69</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga71</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga72</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga73</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd153</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd154</id>
		<comp>0.000006</comp>
	</nuclide>
	<nuclide>
		<id>Gd155</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd156</id>
		<comp>0.000128</comp>
	</nuclide>
	<nuclide>
		<id>Gd157</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd158</id>
		<comp>0.000033</comp>
	</nuclide>
	<nuclide>
		<id>Gd159</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd160</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Gd161</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd162</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd164</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge72</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge73</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge74</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge75</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge76</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Ge77</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge78</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge79</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge80</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge81</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>H3</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>He4</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Ho165</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ho166</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ho166m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I127</id>
		<comp>0.000082</comp>
	</nuclide>
	<nuclide>
		<id>I128</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I129</id>
		<comp>0.000272</comp>
	</nuclide>
	<nuclide>
		<id>I130</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I130m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I131</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>I132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I133</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>I133m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I134</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I134m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I135</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I136</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I136m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I137</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I138</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I139</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In114m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In115</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>In115m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In116</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In116m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In117</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In117m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In119</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In119m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In120</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In121</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In121m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In122</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In123m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In125m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In128</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr80</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr81</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr82</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Kr83</id>
		<comp>0.000058</comp>
	</nuclide>
	<nuclide>
		<id>Kr83m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr84</id>
		<comp>0.000173</comp>
	</nuclide>
	<nuclide>
		<id>Kr85</id>
		<comp>0.000034</comp>
	</nuclide>
	<nuclide>
		<id>Kr85m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr86</id>
		<comp>0.000282</comp>
	</nuclide>
	<nuclide>
		<id>Kr87</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr88</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr89</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr90</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr91</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr92</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La138</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La139</id>
		<comp>0.001849</comp>
	</nuclide>
	<nuclide>
		<id>La140</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>La141</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La143</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La144</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La145</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La147</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La148</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Li6</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Li7</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo100</id>
		<comp>0.001419</comp>
	</nuclide>
	<nuclide>
		<id>Mo101</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo103</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo104</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo105</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo106</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Mo95</id>
		<comp>0.001010</comp>
	</nuclide>
	<nuclide>
		<id>Mo96</id>
		<comp>0.000081</comp>
	</nuclide>
	<nuclide>
		<id>Mo97</id>
		<comp>0.001200</comp>
	</nuclide>
	<nuclide>
		<id>Mo98</id>
		<comp>0.001239</comp>
	</nuclide>
	<nuclide>
		<id>Mo99</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Nb100</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb100m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb101</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb103</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb104</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb105</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb93</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb93m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb94</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb95</id>
		<comp>0.000037</comp>
	</nuclide>
	<nuclide>
		<id>Nb95m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb96</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb97</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb97m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb98</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb98m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb99</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb99m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd142</id>
		<comp>0.000052</comp>
	</nuclide>
	<nuclide>
		<id>Nd143</id>
		<comp>0.001090</comp>
	</nuclide>
	<nuclide>
		<id>Nd144</id>
		<comp>0.001689</comp>
	</nuclide>
	<nuclide>
		<id>Nd145</id>
		<comp>0.000975</comp>
	</nuclide>
	<nuclide>
		<id>Nd146</id>
		<comp>0.001090</comp>
	</nuclide>
	<nuclide>
		<id>Nd147</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>Nd148</id>
		<comp>0.000563</comp>
	</nuclide>
	<nuclide>
		<id>Nd149</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd150</id>
		<comp>0.000274</comp>
	</nuclide>
	<nuclide>
		<id>Nd151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd153</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd154</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd155</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nd156</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Np236</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Np237</id>
		<comp>0.000636</comp>
	</nuclide>
	<nuclide>
		<id>Np238</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Np239</id>
		<comp>0.000089</comp>
	</nuclide>
	<nuclide>
		<id>Np240</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pa231</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pa232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pa233</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pb208</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd104</id>
		<comp>0.000465</comp>
	</nuclide>
	<nuclide>
		<id>Pd105</id>
		<comp>0.000610</comp>
	</nuclide>
	<nuclide>
		<id>Pd106</id>
		<comp>0.000376</comp>
	</nuclide>
	<nuclide>
		<id>Pd107</id>
		<comp>0.000361</comp>
	</nuclide>
	<nuclide>
		<id>Pd108</id>
		<comp>0.000249</comp>
	</nuclide>
	<nuclide>
		<id>Pd109</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd109m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd110</id>
		<comp>0.000082</comp>
	</nuclide>
	<nuclide>
		<id>Pd111</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd111m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd112</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd114</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd115</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd116</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm147</id>
		<comp>0.000145</comp>
	</nuclide>
	<nuclide>
		<id>Pm148</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Pm148m</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Pm149</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Pm150</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm152m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm153</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm154</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm154m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm155</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm156</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pm157</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr141</id>
		<comp>0.001639</comp>
	</nuclide>
	<nuclide>
		<id>Pr142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr142m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr143</id>
		<comp>0.000019</comp>
	</nuclide>
	<nuclide>
		<id>Pr144</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr144m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr145</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr147</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr148</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr149</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr150</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr153</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pu237</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pu238</id>
		<comp>0.000301</comp>
	</nuclide>
	<nuclide>
		<id>Pu239</id>
		<comp>0.006087</comp>
	</nuclide>
	<nuclide>
		<id>Pu240</id>
		<comp>0.002929</comp>
	</nuclide>
	<nuclide>
		<id>Pu241</id>
		<comp>0.001789</comp>
	</nuclide>
	<nuclide>
		<id>Pu242</id>
		<comp>0.000872</comp>
	</nuclide>
	<nuclide>
		<id>Pu243</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pu244</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb85</id>
		<comp>0.000147</comp>
	</nuclide>
	<nuclide>
		<id>Rb86</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb87</id>
		<comp>0.000362</comp>
	</nuclide>
	<nuclide>
		<id>Rb88</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb89</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb90</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb90m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb91</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb92</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb93</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb94</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh103</id>
		<comp>0.000561</comp>
	</nuclide>
	<nuclide>
		<id>Rh103m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh104</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh104m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh105</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Rh105m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh106</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh106m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh108</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh108m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh109</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh110</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh111</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rh112</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru100</id>
		<comp>0.000218</comp>
	</nuclide>
	<nuclide>
		<id>Ru101</id>
		<comp>0.001169</comp>
	</nuclide>
	<nuclide>
		<id>Ru102</id>
		<comp>0.001220</comp>
	</nuclide>
	<nuclide>
		<id>Ru103</id>
		<comp>0.000048</comp>
	</nuclide>
	<nuclide>
		<id>Ru104</id>
		<comp>0.000863</comp>
	</nuclide>
	<nuclide>
		<id>Ru105</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru106</id>
		<comp>0.000215</comp>
	</nuclide>
	<nuclide>
		<id>Ru107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru108</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru109</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru110</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru111</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru99</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb121</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sb122</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb123</id>
		<comp>0.000015</comp>
	</nuclide>
	<nuclide>
		<id>Sb124</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb125</id>
		<comp>0.000019</comp>
	</nuclide>
	<nuclide>
		<id>Sb126</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb126m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb127</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb128</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb128m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb129</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb130</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb130m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb131</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb132m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb133</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb134</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb134m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se76</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se77</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Se78</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Se79</id>
		<comp>0.000009</comp>
	</nuclide>
	<nuclide>
		<id>Se79m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se80</id>
		<comp>0.000020</comp>
	</nuclide>
	<nuclide>
		<id>Se81</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se81m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se82</id>
		<comp>0.000050</comp>
	</nuclide>
	<nuclide>
		<id>Se83</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se83m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se84</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se85</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se86</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se87</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm146</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm147</id>
		<comp>0.000094</comp>
	</nuclide>
	<nuclide>
		<id>Sm148</id>
		<comp>0.000310</comp>
	</nuclide>
	<nuclide>
		<id>Sm149</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>Sm150</id>
		<comp>0.000471</comp>
	</nuclide>
	<nuclide>
		<id>Sm151</id>
		<comp>0.000022</comp>
	</nuclide>
	<nuclide>
		<id>Sm152</id>
		<comp>0.000177</comp>
	</nuclide>
	<nuclide>
		<id>Sm153</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Sm154</id>
		<comp>0.000060</comp>
	</nuclide>
	<nuclide>
		<id>Sm155</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm156</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm157</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm158</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm159</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sm160</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn114</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn115</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn116</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sn117</id>
		<comp>0.000013</comp>
	</nuclide>
	<nuclide>
		<id>Sn117m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn118</id>
		<comp>0.000013</comp>
	</nuclide>
	<nuclide>
		<id>Sn119</id>
		<comp>0.000013</comp>
	</nuclide>
	<nuclide>
		<id>Sn119m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn120</id>
		<comp>0.000013</comp>
	</nuclide>
	<nuclide>
		<id>Sn121</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn121m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn122</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>Sn123</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn123m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn124</id>
		<comp>0.000019</comp>
	</nuclide>
	<nuclide>
		<id>Sn125</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn125m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn126</id>
		<comp>0.000042</comp>
	</nuclide>
	<nuclide>
		<id>Sn127</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn127m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn128</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn129</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn129m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn130</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn131</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr86</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Sr87</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr88</id>
		<comp>0.000519</comp>
	</nuclide>
	<nuclide>
		<id>Sr89</id>
		<comp>0.000025</comp>
	</nuclide>
	<nuclide>
		<id>Sr90</id>
		<comp>0.000777</comp>
	</nuclide>
	<nuclide>
		<id>Sr91</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr92</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr93</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr94</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr95</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr96</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr98</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tb159</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Tb160</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tb161</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tb162</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tb163</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc100</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc101</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc102m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc103</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc104</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc105</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc106</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc108</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc109</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc98</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc99</id>
		<comp>0.001129</comp>
	</nuclide>
	<nuclide>
		<id>Tc99m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te122</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te123</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te123m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te124</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te125</id>
		<comp>0.000010</comp>
	</nuclide>
	<nuclide>
		<id>Te125m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te126</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te127</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te127m</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Te128</id>
		<comp>0.000171</comp>
	</nuclide>
	<nuclide>
		<id>Te129</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te129m</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Te130</id>
		<comp>0.000547</comp>
	</nuclide>
	<nuclide>
		<id>Te131</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te131m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te132</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Te133</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te133m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te134</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te135</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te136</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te137</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th228</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th230</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th231</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th234</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tm169</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tm170</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tm171</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U233</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U234</id>
		<comp>0.000169</comp>
	</nuclide>
	<nuclide>
		<id>U235</id>
		<comp>0.007405</comp>
	</nuclide>
	<nuclide>
		<id>U236</id>
		<comp>0.005516</comp>
	</nuclide>
	<nuclide>
		<id>U237</id>
		<comp>0.000011</comp>
	</nuclide>
	<nuclide>
		<id>U238</id>
		<comp>0.921659</comp>
	</nuclide>
	<nuclide>
		<id>U239</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>U240</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe127</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe128</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>Xe129</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe129m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe130</id>
		<comp>0.000023</comp>
	</nuclide>
	<nuclide>
		<id>Xe131</id>
		<comp>0.000558</comp>
	</nuclide>
	<nuclide>
		<id>Xe131m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe132</id>
		<comp>0.001749</comp>
	</nuclide>
	<nuclide>
		<id>Xe133</id>
		<comp>0.000010</comp>
	</nuclide>
	<nuclide>
		<id>Xe133m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe134</id>
		<comp>0.002249</comp>
	</nuclide>
	<nuclide>
		<id>Xe135</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe135m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe136</id>
		<comp>0.003398</comp>
	</nuclide>
	<nuclide>
		<id>Xe137</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe138</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe139</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe140</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe141</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y100</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y89</id>
		<comp>0.000651</comp>
	</nuclide>
	<nuclide>
		<id>Y90</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y90m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y91</id>
		<comp>0.000039</comp>
	</nuclide>
	<nuclide>
		<id>Y91m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y92</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y93</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y94</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y95</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y96</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y97</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y98</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Y99</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Yb170</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Yb171</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zn68</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zn70</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zn72</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr100</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr101</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr103</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr104</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr90</id>
		<comp>0.000044</comp>
	</nuclide>
	<nuclide>
		<id>Zr91</id>
		<comp>0.000838</comp>
	</nuclide>
	<nuclide>
		<id>Zr92</id>
		<comp>0.000955</comp>
	</nuclide>
	<nuclide>
		<id>Zr93</id>
		<comp>0.001069</comp>
	</nuclide>
	<nuclide>
		<id>Zr94</id>
		<comp>0.001129</comp>
	</nuclide>
	<nuclide>
		<id>Zr95</id>
		<comp>0.000067</comp>
	</nuclide>
	<nuclide>
		<id>Zr96</id>
		<comp>0.001210</comp>
	</nuclide>
	<nuclide>
		<id>Zr97</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Zr98</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Zr99</id>
		<comp>0.000000</comp>
	</nuclide>
</recipe>

<recipe> 
	<name>EG02_used_recipe</name>
	<basis>mass</basis>
	<nuclide>
		<id>Ag107</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ag109</id>
		<comp>0.000174</comp>
	</nuclide>
	<nuclide>
		<id>Ag110m</id>
		<comp>0.000076</comp>
	</nuclide>
	<nuclide>
		<id>Ag111</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Am241</id>
		<comp>0.000191</comp>
	</nuclide>
	<nuclide>
		<id>Am242</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Am242m</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>Am243</id>
		<comp>0.000438</comp>
	</nuclide>
	<nuclide>
		<id>Am244</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Am244m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>As75</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba132</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba133</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ba134</id>
		<comp>0.000247</comp>
	</nuclide>
	<nuclide>
		<id>Ba135</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Ba136</id>
		<comp>0.000094</comp>
	</nuclide>
	<nuclide>
		<id>Ba137</id>
		<comp>0.000253</comp>
	</nuclide>
	<nuclide>
		<id>Ba138</id>
		<comp>0.004813</comp>
	</nuclide>
	<nuclide>
		<id>Ba140</id>
		<comp>0.000042</comp>
	</nuclide>
	<nuclide>
		<id>Br79</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Br81</id>
		<comp>0.000079</comp>
	</nuclide>
	<nuclide>
		<id>Cd108</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd110</id>
		<comp>0.000045</comp>
	</nuclide>
	<nuclide>
		<id>Cd111</id>
		<comp>0.000070</comp>
	</nuclide>
	<nuclide>
		<id>Cd112</id>
		<comp>0.000034</comp>
	</nuclide>
	<nuclide>
		<id>Cd113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd114</id>
		<comp>0.000040</comp>
	</nuclide>
	<nuclide>
		<id>Cd115m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Cd116</id>
		<comp>0.000015</comp>
	</nuclide>
	<nuclide>
		<id>Ce139</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ce140</id>
		<comp>0.004422</comp>
	</nuclide>
	<nuclide>
		<id>Ce141</id>
		<comp>0.000102</comp>
	</nuclide>
	<nuclide>
		<id>Ce142</id>
		<comp>0.004158</comp>
	</nuclide>
	<nuclide>
		<id>Ce143</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Ce144</id>
		<comp>0.000819</comp>
	</nuclide>
	<nuclide>
		<id>Cm242</id>
		<comp>0.000071</comp>
	</nuclide>
	<nuclide>
		<id>Cm243</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Cm244</id>
		<comp>0.000131</comp>
	</nuclide>
	<nuclide>
		<id>Cm245</id>
		<comp>0.000009</comp>
	</nuclide>
	<nuclide>
		<id>Cs133</id>
		<comp>0.004025</comp>
	</nuclide>
	<nuclide>
		<id>Cs134</id>
		<comp>0.000421</comp>
	</nuclide>
	<nuclide>
		<id>Cs135</id>
		<comp>0.002459</comp>
	</nuclide>
	<nuclide>
		<id>Cs136</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Cs137</id>
		<comp>0.004414</comp>
	</nuclide>
	<nuclide>
		<id>Dy160</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy161</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy162</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Dy163</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Dy164</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er166</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er167</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er168</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Er170</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Eu153</id>
		<comp>0.000411</comp>
	</nuclide>
	<nuclide>
		<id>Eu154</id>
		<comp>0.000073</comp>
	</nuclide>
	<nuclide>
		<id>Eu155</id>
		<comp>0.000019</comp>
	</nuclide>
	<nuclide>
		<id>Eu156</id>
		<comp>0.000008</comp>
	</nuclide>
	<nuclide>
		<id>Eu157</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga69</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ga71</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd152</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd153</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd154</id>
		<comp>0.000009</comp>
	</nuclide>
	<nuclide>
		<id>Gd155</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Gd156</id>
		<comp>0.000240</comp>
	</nuclide>
	<nuclide>
		<id>Gd157</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Gd158</id>
		<comp>0.000051</comp>
	</nuclide>
	<nuclide>
		<id>Gd160</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>Ge70</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge72</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge73</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge74</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ge76</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>He4</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>Ho165</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ho166m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I127</id>
		<comp>0.000153</comp>
	</nuclide>
	<nuclide>
		<id>I129</id>
		<comp>0.000506</comp>
	</nuclide>
	<nuclide>
		<id>I130</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>I131</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>I135</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>In113</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>In115</id>
		<comp>0.000005</comp>
	</nuclide>
	<nuclide>
		<id>Kr80</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Kr82</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Kr83</id>
		<comp>0.000160</comp>
	</nuclide>
	<nuclide>
		<id>Kr84</id>
		<comp>0.000341</comp>
	</nuclide>
	<nuclide>
		<id>Kr85</id>
		<comp>0.000071</comp>
	</nuclide>
	<nuclide>
		<id>Kr86</id>
		<comp>0.000643</comp>
	</nuclide>
	<nuclide>
		<id>La138</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>La139</id>
		<comp>0.004537</comp>
	</nuclide>
	<nuclide>
		<id>La140</id>
		<comp>0.000006</comp>
	</nuclide>
	<nuclide>
		<id>Mo100</id>
		<comp>0.003376</comp>
	</nuclide>
	<nuclide>
		<id>Mo95</id>
		<comp>0.002620</comp>
	</nuclide>
	<nuclide>
		<id>Mo96</id>
		<comp>0.000156</comp>
	</nuclide>
	<nuclide>
		<id>Mo97</id>
		<comp>0.002162</comp>
	</nuclide>
	<nuclide>
		<id>Mo98</id>
		<comp>0.002972</comp>
	</nuclide>
	<nuclide>
		<id>Mo99</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>Nb93</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb94</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Nb95</id>
		<comp>0.000078</comp>
	</nuclide>
	<nuclide>
		<id>Nd142</id>
		<comp>0.000068</comp>
	</nuclide>
	<nuclide>
		<id>Nd143</id>
		<comp>0.003088</comp>
	</nuclide>
	<nuclide>
		<id>Nd144</id>
		<comp>0.003964</comp>
	</nuclide>
	<nuclide>
		<id>Nd145</id>
		<comp>0.002484</comp>
	</nuclide>
	<nuclide>
		<id>Nd146</id>
		<comp>0.002535</comp>
	</nuclide>
	<nuclide>
		<id>Nd147</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>Nd148</id>
		<comp>0.001314</comp>
	</nuclide>
	<nuclide>
		<id>Nd150</id>
		<comp>0.000600</comp>
	</nuclide>
	<nuclide>
		<id>Np236</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Np237</id>
		<comp>0.001766</comp>
	</nuclide>
	<nuclide>
		<id>Np238</id>
		<comp>0.000004</comp>
	</nuclide>
	<nuclide>
		<id>Np239</id>
		<comp>0.000134</comp>
	</nuclide>
	<nuclide>
		<id>Pa231</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pa232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pa233</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd102</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pd104</id>
		<comp>0.000772</comp>
	</nuclide>
	<nuclide>
		<id>Pd105</id>
		<comp>0.001240</comp>
	</nuclide>
	<nuclide>
		<id>Pd106</id>
		<comp>0.000710</comp>
	</nuclide>
	<nuclide>
		<id>Pd107</id>
		<comp>0.000654</comp>
	</nuclide>
	<nuclide>
		<id>Pd108</id>
		<comp>0.000437</comp>
	</nuclide>
	<nuclide>
		<id>Pd110</id>
		<comp>0.000147</comp>
	</nuclide>
	<nuclide>
		<id>Pm147</id>
		<comp>0.000539</comp>
	</nuclide>
	<nuclide>
		<id>Pm148</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Pm148m</id>
		<comp>0.000009</comp>
	</nuclide>
	<nuclide>
		<id>Pm149</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Pm151</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr141</id>
		<comp>0.004016</comp>
	</nuclide>
	<nuclide>
		<id>Pr142</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pr143</id>
		<comp>0.000040</comp>
	</nuclide>
	<nuclide>
		<id>Pu237</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pu238</id>
		<comp>0.000766</comp>
	</nuclide>
	<nuclide>
		<id>Pu239</id>
		<comp>0.010010</comp>
	</nuclide>
	<nuclide>
		<id>Pu240</id>
		<comp>0.004572</comp>
	</nuclide>
	<nuclide>
		<id>Pu241</id>
		<comp>0.004580</comp>
	</nuclide>
	<nuclide>
		<id>Pu242</id>
		<comp>0.002223</comp>
	</nuclide>
	<nuclide>
		<id>Pu243</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Pu244</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb85</id>
		<comp>0.000240</comp>
	</nuclide>
	<nuclide>
		<id>Rb86</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Rb87</id>
		<comp>0.000935</comp>
	</nuclide>
	<nuclide>
		<id>Rh103</id>
		<comp>0.001448</comp>
	</nuclide>
	<nuclide>
		<id>Rh105</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Ru100</id>
		<comp>0.000403</comp>
	</nuclide>
	<nuclide>
		<id>Ru101</id>
		<comp>0.002765</comp>
	</nuclide>
	<nuclide>
		<id>Ru102</id>
		<comp>0.002768</comp>
	</nuclide>
	<nuclide>
		<id>Ru103</id>
		<comp>0.000083</comp>
	</nuclide>
	<nuclide>
		<id>Ru104</id>
		<comp>0.001768</comp>
	</nuclide>
	<nuclide>
		<id>Ru105</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Ru106</id>
		<comp>0.000355</comp>
	</nuclide>
	<nuclide>
		<id>Ru99</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb121</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sb123</id>
		<comp>0.000015</comp>
	</nuclide>
	<nuclide>
		<id>Sb124</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sb125</id>
		<comp>0.000022</comp>
	</nuclide>
	<nuclide>
		<id>Sb126</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se76</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Se77</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>Se78</id>
		<comp>0.000008</comp>
	</nuclide>
	<nuclide>
		<id>Se79</id>
		<comp>0.000017</comp>
	</nuclide>
	<nuclide>
		<id>Se80</id>
		<comp>0.000049</comp>
	</nuclide>
	<nuclide>
		<id>Se82</id>
		<comp>0.000126</comp>
	</nuclide>
	<nuclide>
		<id>Sm147</id>
		<comp>0.000391</comp>
	</nuclide>
	<nuclide>
		<id>Sm148</id>
		<comp>0.000527</comp>
	</nuclide>
	<nuclide>
		<id>Sm149</id>
		<comp>0.000010</comp>
	</nuclide>
	<nuclide>
		<id>Sm150</id>
		<comp>0.000969</comp>
	</nuclide>
	<nuclide>
		<id>Sm151</id>
		<comp>0.000058</comp>
	</nuclide>
	<nuclide>
		<id>Sm152</id>
		<comp>0.000346</comp>
	</nuclide>
	<nuclide>
		<id>Sm153</id>
		<comp>0.000002</comp>
	</nuclide>
	<nuclide>
		<id>Sm154</id>
		<comp>0.000114</comp>
	</nuclide>
	<nuclide>
		<id>Sn114</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn115</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Sn116</id>
		<comp>0.000008</comp>
	</nuclide>
	<nuclide>
		<id>Sn117</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>Sn118</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sn119</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sn120</id>
		<comp>0.000012</comp>
	</nuclide>
	<nuclide>
		<id>Sn122</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>Sn123</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Sn124</id>
		<comp>0.000027</comp>
	</nuclide>
	<nuclide>
		<id>Sn125</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sn126</id>
		<comp>0.000063</comp>
	</nuclide>
	<nuclide>
		<id>Sr86</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Sr87</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Sr88</id>
		<comp>0.001317</comp>
	</nuclide>
	<nuclide>
		<id>Sr89</id>
		<comp>0.000058</comp>
	</nuclide>
	<nuclide>
		<id>Sr90</id>
		<comp>0.002101</comp>
	</nuclide>
	<nuclide>
		<id>Tb159</id>
		<comp>0.000007</comp>
	</nuclide>
	<nuclide>
		<id>Tb160</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Tc99</id>
		<comp>0.002817</comp>
	</nuclide>
	<nuclide>
		<id>Te122</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te123</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te124</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te125</id>
		<comp>0.000014</comp>
	</nuclide>
	<nuclide>
		<id>Te126</id>
		<comp>0.000003</comp>
	</nuclide>
	<nuclide>
		<id>Te127m</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Te128</id>
		<comp>0.000305</comp>
	</nuclide>
	<nuclide>
		<id>Te129m</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Te130</id>
		<comp>0.001328</comp>
	</nuclide>
	<nuclide>
		<id>Te132</id>
		<comp>0.000008</comp>
	</nuclide>
	<nuclide>
		<id>Th228</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th229</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th230</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Th234</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U232</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U233</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>U234</id>
		<comp>0.001866</comp>
	</nuclide>
	<nuclide>
		<id>U235</id>
		<comp>0.048592</comp>
	</nuclide>
	<nuclide>
		<id>U236</id>
		<comp>0.019611</comp>
	</nuclide>
	<nuclide>
		<id>U237</id>
		<comp>0.000026</comp>
	</nuclide>
	<nuclide>
		<id>U238</id>
		<comp>0.782231</comp>
	</nuclide>
	<nuclide>
		<id>U239</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>U240</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe126</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe128</id>
		<comp>0.000010</comp>
	</nuclide>
	<nuclide>
		<id>Xe129</id>
		<comp>0.000000</comp>
	</nuclide>
	<nuclide>
		<id>Xe130</id>
		<comp>0.000018</comp>
	</nuclide>
	<nuclide>
		<id>Xe131</id>
		<comp>0.001491</comp>
	</nuclide>
	<nuclide>
		<id>Xe132</id>
		<comp>0.003855</comp>
	</nuclide>
	<nuclide>
		<id>Xe133</id>
		<comp>0.000019</comp>
	</nuclide>
	<nuclide>
		<id>Xe134</id>
		<comp>0.005518</comp>
	</nuclide>
	<nuclide>
		<id>Xe135</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Xe136</id>
		<comp>0.006947</comp>
	</nuclide>
	<nuclide>
		<id>Y89</id>
		<comp>0.001720</comp>
	</nuclide>
	<nuclide>
		<id>Y90</id>
		<comp>0.000001</comp>
	</nuclide>
	<nuclide>
		<id>Y91</id>
		<comp>0.000090</comp>
	</nuclide>
	<nuclide>
		<id>Zr90</id>
		<comp>0.000137</comp>
	</nuclide>
	<nuclide>
		<id>Zr91</id>
		<comp>0.002203</comp>
	</nuclide>
	<nuclide>
		<id>Zr92</id>
		<comp>0.002446</comp>
	</nuclide>
	<nuclide>
		<id>Zr93</id>
		<comp>0.002636</comp>
	</nuclide>
	<nuclide>
		<id>Zr94</id>
		<comp>0.002924</comp>
	</nuclide>
	<nuclide>
		<id>Zr95</id>
		<comp>0.000140</comp>
	</nuclide>
	<nuclide>
		<id>Zr96</id>
		<comp>0.002972</comp>
	</nuclide>
</recipe>"""

# %%
# build recipe file
output_file = 'recipe.xml'

output = open(output_file, 'w')

pu_comp_dict = {}
output.write('<root>\n')
for i in range(1, len(array[0])):
    pu_inv = 0
    output.write('<recipe>\n'
                 '\t<name>%s</name>\n'
                 '\t<basis>mass</basis>\n' %array[0][i])
    for j in range(1,len(array)):
        if float(array[j][i]) < 1e-7 or array[j][0] == 'TOTAL':
            total = array[j][i]
            continue
        if 'PU' in array[j][0]:
            pu_inv += float(array[j][i])
        output.write('\t<nuclide>\n'
                     '\t\t<id>%s</id>\n'
                     '\t\t<comp>%s</comp>\n'
                     '\t</nuclide>\n' %(array[j][0], array[j][i]))
    pu_comp_dict[array[0][i]] = pu_inv / float(total)
    output.write('</recipe>\n\n')

# eg01 (lwr) compositions
output.write(string)
output.write('\n')
output.write('</root>')
# Out:
# 7

# %%
# the mixture ratio of blanket / driver, to obtain BR:
br = 1.2
driver_ratio = -1.0 * pu_comp_dict['blanket_used'] / (pu_comp_dict['driver_used'] - pu_comp_dict['blanket_used'] - br * pu_comp_dict['driver_fresh'])
print(driver_ratio)
# Out:
# 0.5896059548553455

# %%
# thus, among the 37.45 tHM core size of the SFR,
# 59 percent should be driver.
driver_core_mass = 37.45 * driver_ratio
driver_batch_mass = driver_core_mass / 6
blanket_core_mass = 37.45 * (1-driver_ratio)
blanket_batch_mass = blanket_core_mass / 6

print(driver_core_mass)
print(driver_batch_mass)
print(blanket_core_mass)
print(blanket_batch_mass)
# Out:
# 22.08074300933269
# 3.6801238348887817
# 15.369256990667312
# 2.5615428317778854

# %%
# this makes the average pu composition to be:
avg_fresh_pu = (driver_core_mass * pu_comp_dict['driver_fresh']) / (driver_core_mass + blanket_core_mass)
avg_used_pu = (driver_core_mass * pu_comp_dict['driver_used'] + blanket_core_mass * pu_comp_dict['blanket_used']) / (driver_core_mass + blanket_core_mass)

print(avg_fresh_pu)
print(avg_used_pu)
print('BR = %f'%(avg_used_pu / avg_fresh_pu))
# Out:
# 0.08998412919825217
# 0.1079809550379026
# BR = 1.200000

# %%
# !cat recipe.xml
# Out:
# <root>
# <recipe>
# 	<name>driver_fresh</name>
# 	<basis>mass</basis>
# 	<nuclide>
# 		<id>U234</id>
# 		<comp>5.454e+01</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>U235</id>
# 		<comp>6.271e+00</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>U236</id>
# 		<comp>8.604e+02</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>U238</id>
# 		<comp>8.464e+05</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU236</id>
# 		<comp>2.279e-03</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU238</id>
# 		<comp>4.044e+02</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU239</id>
# 		<comp>1.038e+05</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU240</id>
# 		<comp>4.091e+04</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU241</id>
# 		<comp>4.767e+03</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>PU242</id>
# 		<comp>2.736e+03</comp>
# 	</nuclide>
# 	<nuclide>
# 		<id>TOTAL</id>
# 		<comp>1.000e+06</comp>
# 	</nuclide>
# </recipe>
#
# <recipe>
# 	<name>driver_used</name>
# 	<basis>mass</basis>
# 	<nuclide>
# 		<id>H3</id>
# ...
